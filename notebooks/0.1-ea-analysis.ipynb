# %%
import pandas as pd

# %%
data = pd.read_csv("../results/gross_daily.csv", index_col=0)

# %%
data.drop(columns=["volume", "inflow", "outflow"]).plot()

# %%
data = data.drop(columns=["volume", "inflow", "outflow"])
import matplotlib.pyplot as plt

# %%
data.diff().plot()
